# %%
import sqlite3

# %%
con = sqlite3.connect(r"d:\Shooting\FPSsci\results\weaponsample_Sample_User_5e52c108.db")

# %%
cursor = con.cursor()
cursor.execute('SELECT * FROM users')
users = cursor.fetchall()

# %%
frame_info = cursor.execute('SELECT * FROM frame_info').fetchall()

# %%
import matplotlib.pyplot as plt
dates = [item[0] for item in frame_info]
numbers = [item[1] for item in frame_info]
plt.plot(dates[:500], numbers[:500])
# plt.plot()
